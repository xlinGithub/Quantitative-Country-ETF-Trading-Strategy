# %%
#import the working library
import numpy as np
import pandas as pd
import os
from scipy.stats.mstats import winsorize
from scipy.stats import zscore
# %matplotlib inline

# %%
#read tickers as specified in excel in addition to market 
all_tickers = pd.read_excel('mapping.xlsx')[['Ticker', 'Market', 'Include']]
#list all tickers
all_tickers = all_tickers[all_tickers['Include']]
all_tickers
# Out:
#    Ticker     Market  Include
# 0    ARGT   Emerging     True
# 1     EWA  Developed     True
# 2     EWO  Developed     True
# 3     EWK  Developed     True
# 4     EWZ   Emerging     True
# 5     EWC  Developed     True
# 6     ECH   Emerging     True
# 7    MCHI   Emerging     True
# 12    EWQ  Developed     True
# 13    EWG  Developed     True
# 14   GREK   Emerging     True
# 15    EWH  Developed     True
# 17   EIDO   Emerging     True
# 20    EWI  Developed     True
# 21    EWJ  Developed     True
# 22    EWY   Emerging     True
# 23    EWM   Emerging     True
# 24    EWW   Emerging     True
# 25    EWN  Developed     True
# 26   ENZL  Developed     True
# 29    EPU   Emerging     True
# 30   EPHE   Emerging     True
# 31   EPOL   Emerging     True
# 34   ERUS   Emerging     True
# 35    KSA   Emerging     True
# 36    EWS  Developed     True
# 37    EZA   Emerging     True
# 38    EWP  Developed     True
# 39    EWD  Developed     True
# 40    EWL  Developed     True
# 41    EWT   Emerging     True
# 42    THD   Emerging     True
# 43    TUR   Emerging     True
# 45    EWU  Developed     True
# 46    VOO  Developed     True

# %%
factor_description = pd.read_excel('factor description.xlsx', index_col='Short Name')
factor_description
# Out:
#                                                               Name  \
# Short Name
# mom_21               Short-term Absolute Momentum (21-trading day)
# mom_63              Medium-term Absolute Momentum (63-trading day)
# mom_252              Long-term Absolute Momentum (252-trading day)
# mr_21            Percentage over Short-term Moving Average (21-...
# mr_63            Percentage over Medium-term Moving Average (63...
# mr_252           Percentage over Long-term Moving Average (252-...
# div_yield                                           Dividend Yield
# pb                                                Price/Book Ratio
# pe                                             Price/Earning Ratio
# pcf                                          Price/Cash Flow Ratio
# pmi                                                            PMI
# gdp_growth                                          QoQ GDP Growth
# debt_gdp                                   National Debt/GDP Ratio
# reer                                                          REER
# pc_ratio                                            Put/Call Ratio
# short_int                                           Short Interest
# short_int_ratio               Short Interest/Market Capitalization
# f_flow                                                   Fund Flow
# sh_out                                           Share Outstanding
# mkt_cap                                      Market Capitalization
# f_rtn                   Forward Return (one month, 21-trading day)
#
#                                     Category
# Short Name
# mom_21                             Technical
# mom_63                             Technical
# mom_252                            Technical
# mr_21                              Technical
# mr_63                              Technical
# mr_252                             Technical
# div_yield                        Fundamental
# pb                               Fundamental
# pe                               Fundamental
# pcf                              Fundamental
# pmi                                 Economic
# gdp_growth                          Economic
# debt_gdp                            Economic
# reer                                Economic
# pc_ratio         Sentimental and Alternative
# short_int        Sentimental and Alternative
# short_int_ratio  Sentimental and Alternative
# f_flow           Sentimental and Alternative
# sh_out                                   NaN
# mkt_cap                                  NaN
# f_rtn                                    NaN

# %%
#specified factor and date
start_date_train = '2016-01-01'
end_date_train = '2018-12-31'
start_date_test = '2019-01-01'
end_date_test = '2019-12-31'

# %% [markdown]
# # Technical Factors

# %%
factors = ['mom_252', 'mom_63', 'mom_21', 
           'mr_252', 'mr_63', 'mr_21']

# %%
all_etf_all_factor_df = None
for factor_to_analyze in factors:
    description_factor_to_analyze = factor_description.loc[factor_to_analyze, 'Name']
    print(description_factor_to_analyze)

    #list all etf in datafrome
    all_etf_combined_df = pd.DataFrame()

    #going throw each etf forward return 
    for file in os.listdir('forward return'):
        fr_df = pd.read_csv('forward return/'+file, index_col='Date')
        fr_df['Ticker'] = file[:-4]
        try:
            factor_df = pd.read_csv('factor data/'+factor_to_analyze+'/'+file[:-4]+'.csv', index_col='Date')
            combined_df = fr_df.join(factor_df).rename({factor_to_analyze: 'Factor'}, axis=1)
            combined_df['Factor'] = combined_df['Factor'].fillna(method='ffill')
            all_etf_combined_df = pd.concat([all_etf_combined_df, combined_df.dropna().reset_index()], axis=0, ignore_index=True)
        except:
            continue
    
    all_etf_combined_df = all_etf_combined_df.join(all_tickers.set_index('Ticker'), on='Ticker').dropna()
    all_etf_combined_df = all_etf_combined_df.sort_values(['Date', 'Market', 'Ticker']).set_index(['Date', 'Market', 'Ticker'])[start_date_train:end_date_test]
    all_etf_combined_df['Winsorized Factor'] = np.nan
    all_etf_combined_df['Normalized Winsorized Factor'] = np.nan

    #combine all factors
    for date in all_etf_combined_df.index.get_level_values(0).unique():
        for market in ['Developed', 'Emerging']:
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            if n_etf >= 15:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = winsorize(all_etf_combined_df.loc[date].loc[market]['Factor'], limits=1/n_etf)
            elif n_etf > 0:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = all_etf_combined_df.loc[date].loc[market]['Factor']
            all_etf_combined_df.loc[date].loc[market]['Normalized Winsorized Factor'] = zscore(all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'])
    all_etf_combined_df = all_etf_combined_df.rename({'Normalized Winsorized Factor': factor_to_analyze}, axis=1)
    if all_etf_all_factor_df is None:
        all_etf_all_factor_df = all_etf_combined_df[['f_rtn', factor_to_analyze]]
    else:
        all_etf_all_factor_df = all_etf_all_factor_df.join(all_etf_combined_df[[factor_to_analyze]], how='outer')
# Out:
# Long-term Absolute Momentum (252-trading day)
# Medium-term Absolute Momentum (63-trading day)
# Short-term Absolute Momentum (21-trading day)
# Percentage over Long-term Moving Average (252-trading day)
# Percentage over Medium-term Moving Average (63-trading day)
# Percentage over Short-term Moving Average (21-trading day)

# %%
all_etf_all_factor_df.reset_index()
# Out:
#              Date     Market Ticker     f_rtn   mom_252    mom_63    mom_21  \
# 0      2016-01-04  Developed   ENZL -0.035457  0.302985  1.561762  2.005201
# 1      2016-01-04  Developed    EWA -0.071979 -0.818541  1.183367  0.877727
# 2      2016-01-04  Developed    EWC -0.013368 -1.876307 -1.625714 -1.385869
# 3      2016-01-04  Developed    EWD -0.060830 -0.192694 -0.601391 -1.026347
# 4      2016-01-04  Developed    EWG -0.055149 -0.039418  0.630081 -0.672669
# ...           ...        ...    ...       ...       ...       ...       ...
# 35170  2019-12-30   Emerging   GREK -0.038922  2.182578  0.248636 -0.403086
# 35171  2019-12-30   Emerging    KSA -0.021221 -0.476315 -1.026486 -0.254276
# 35172  2019-12-30   Emerging   MCHI -0.042813  0.552846  1.214980  0.164630
# 35173  2019-12-30   Emerging    THD -0.082510 -0.423942 -1.501269 -1.660978
# 35174  2019-12-30   Emerging    TUR  0.032103 -0.037189 -0.885508 -0.488079
#
#          mr_252     mr_63     mr_21
# 0      1.970015  1.891595  2.293367
# 1     -0.222320  1.475917  2.293367
# 2     -1.443837 -1.532190 -0.567871
# 3     -0.496283 -0.379806 -0.578059
# 4     -0.327268 -0.178206 -1.153282
# ...         ...       ...       ...
# 35170  1.538438  0.172329  0.134355
# 35171 -1.018996 -0.205677 -0.982870
# 35172  0.599531  1.017835  0.578072
# 35173 -0.933935 -1.494013 -1.033223
# 35174  0.670851  0.417986 -0.594872
#
# [35175 rows x 10 columns]

# %%
all_etf_all_factor_df.reset_index().to_csv('modeling data/technical.csv')

# %% [markdown]
# # Fundamental Factors

# %%
factors = ['div_yield', 'pe', 'pb', 'pcf']

# %%
all_etf_all_factor_df = None
for factor_to_analyze in factors:
    description_factor_to_analyze = factor_description.loc[factor_to_analyze, 'Name']
    print(description_factor_to_analyze)

    #list all etf in datafrome
    all_etf_combined_df = pd.DataFrame()

    #going throw each etf forward return 
    for file in os.listdir('forward return'):
        fr_df = pd.read_csv('forward return/'+file, index_col='Date')
        fr_df['Ticker'] = file[:-4]
        try:
            factor_df = pd.read_csv('factor data/'+factor_to_analyze+'/'+file[:-4]+'.csv', index_col='Date')
            combined_df = fr_df.join(factor_df).rename({factor_to_analyze: 'Factor'}, axis=1)
            combined_df['Factor'] = combined_df['Factor'].fillna(method='ffill')
            all_etf_combined_df = pd.concat([all_etf_combined_df, combined_df.dropna().reset_index()], axis=0, ignore_index=True)
        except:
            continue
    
    all_etf_combined_df = all_etf_combined_df.join(all_tickers.set_index('Ticker'), on='Ticker').dropna()
    all_etf_combined_df = all_etf_combined_df.sort_values(['Date', 'Market', 'Ticker']).set_index(['Date', 'Market', 'Ticker'])[start_date_train:end_date_test]
    all_etf_combined_df['Winsorized Factor'] = np.nan
    all_etf_combined_df['Normalized Winsorized Factor'] = np.nan

    #combine all factors
    for date in all_etf_combined_df.index.get_level_values(0).unique():
        for market in ['Developed', 'Emerging']:
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            if n_etf >= 15:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = winsorize(all_etf_combined_df.loc[date].loc[market]['Factor'], limits=1/n_etf)
            elif n_etf > 0:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = all_etf_combined_df.loc[date].loc[market]['Factor']
            all_etf_combined_df.loc[date].loc[market]['Normalized Winsorized Factor'] = zscore(all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'])
    all_etf_combined_df = all_etf_combined_df.rename({'Normalized Winsorized Factor': factor_to_analyze}, axis=1)
    if all_etf_all_factor_df is None:
        all_etf_all_factor_df = all_etf_combined_df[['f_rtn', factor_to_analyze]]
    else:
        all_etf_all_factor_df = all_etf_all_factor_df.join(all_etf_combined_df[[factor_to_analyze]], how='outer')
# Out:
# Dividend Yield
# Price/Earning Ratio
# Price/Book Ratio
# Price/Cash Flow Ratio

# %%
all_etf_all_factor_df.reset_index()
# Out:
#              Date     Market Ticker     f_rtn  div_yield        pe        pb  \
# 0      2016-01-04  Developed   ENZL -0.035457   1.681060 -0.177125  0.284371
# 1      2016-01-04  Developed    EWA -0.071979   1.545555 -0.258636  0.208013
# 2      2016-01-04  Developed    EWG -0.055149  -0.467115 -0.249682 -0.020659
# 3      2016-01-04  Developed    EWH -0.098062  -0.155762 -1.123668 -1.086060
# 4      2016-01-04  Developed    EWI -0.141762   0.557779  2.912695 -1.279059
# ...           ...        ...    ...       ...        ...       ...       ...
# 31653  2019-12-30   Emerging   GREK -0.038922  -0.340118  1.667498  1.529241
# 31654  2019-12-30   Emerging    KSA -0.021221   1.559869  1.667498  0.594718
# 31655  2019-12-30   Emerging   MCHI -0.042813  -1.400002 -0.360158  0.211644
# 31656  2019-12-30   Emerging    THD -0.082510  -0.196165  0.550064  0.596054
# 31657  2019-12-30   Emerging    TUR  0.032103   0.432299 -1.574264 -1.437581
#
#             pcf
# 0      0.596758
# 1     -0.613292
# 2     -0.735939
# 3      2.674202
# 4     -0.660771
# ...         ...
# 31653  2.102185
# 31654  0.267220
# 31655 -0.377070
# 31656 -0.300105
# 31657 -1.072259
#
# [31658 rows x 8 columns]

# %%
all_etf_all_factor_df.reset_index().to_csv('modeling data/fundamental.csv')

# %% [markdown]
# # Economic Factors

# %%
factors = ['gdp_growth', 'debt_gdp', 'reer']

# %%
all_etf_all_factor_df = None
for factor_to_analyze in factors:
    description_factor_to_analyze = factor_description.loc[factor_to_analyze, 'Name']
    print(description_factor_to_analyze)

    #list all etf in datafrome
    all_etf_combined_df = pd.DataFrame()

    #going throw each etf forward return 
    for file in os.listdir('forward return'):
        fr_df = pd.read_csv('forward return/'+file, index_col='Date')
        fr_df['Ticker'] = file[:-4]
        try:
            factor_df = pd.read_csv('factor data/'+factor_to_analyze+'/'+file[:-4]+'.csv', index_col='Date')
            combined_df = fr_df.join(factor_df).rename({factor_to_analyze: 'Factor'}, axis=1)
            combined_df['Factor'] = combined_df['Factor'].fillna(method='ffill')
            all_etf_combined_df = pd.concat([all_etf_combined_df, combined_df.dropna().reset_index()], axis=0, ignore_index=True)
        except:
            continue
    
    all_etf_combined_df = all_etf_combined_df.join(all_tickers.set_index('Ticker'), on='Ticker').dropna()
    all_etf_combined_df = all_etf_combined_df.sort_values(['Date', 'Market', 'Ticker']).set_index(['Date', 'Market', 'Ticker'])[start_date_train:end_date_test]
    all_etf_combined_df['Winsorized Factor'] = np.nan
    all_etf_combined_df['Normalized Winsorized Factor'] = np.nan

    #combine all factors
    for date in all_etf_combined_df.index.get_level_values(0).unique():
        for market in ['Developed', 'Emerging']:
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            if n_etf >= 15:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = winsorize(all_etf_combined_df.loc[date].loc[market]['Factor'], limits=1/n_etf)
            elif n_etf > 0:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = all_etf_combined_df.loc[date].loc[market]['Factor']
            all_etf_combined_df.loc[date].loc[market]['Normalized Winsorized Factor'] = zscore(all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'])
    all_etf_combined_df = all_etf_combined_df.rename({'Normalized Winsorized Factor': factor_to_analyze}, axis=1)
    if all_etf_all_factor_df is None:
        all_etf_all_factor_df = all_etf_combined_df[['f_rtn', factor_to_analyze]]
    else:
        all_etf_all_factor_df = all_etf_all_factor_df.join(all_etf_combined_df[[factor_to_analyze]], how='outer')
# Out:
# QoQ GDP Growth
# National Debt/GDP Ratio
# REER

# %%
all_etf_all_factor_df.reset_index()
# Out:
#              Date     Market Ticker     f_rtn  gdp_growth  debt_gdp      reer
# 0      2016-01-04  Developed   ENZL -0.035457    1.820232 -1.411809  0.357234
# 1      2016-01-04  Developed    EWA -0.071979    0.603763 -1.119388 -0.911989
# 2      2016-01-04  Developed    EWC -0.013368   -1.144913  0.609708 -1.827849
# 3      2016-01-04  Developed    EWD -0.060830    1.820232 -1.151173 -0.266560
# 4      2016-01-04  Developed    EWG -0.055149   -0.384619 -0.261197 -0.458566
# ...           ...        ...    ...       ...         ...       ...       ...
# 35170  2019-12-30   Emerging   GREK -0.038922    0.184934  1.736160 -0.263181
# 35171  2019-12-30   Emerging    KSA -0.021221   -0.346825 -1.439492  1.250170
# 35172  2019-12-30   Emerging   MCHI -0.042813    1.780211 -1.420993  1.446190
# 35173  2019-12-30   Emerging    THD -0.082510   -0.027770  0.472066  1.446190
# 35174  2019-12-30   Emerging    TUR  0.032103   -0.899854 -0.224728 -1.784874
#
# [35175 rows x 7 columns]

# %%
all_etf_all_factor_df.reset_index().to_csv('modeling data/economic.csv')

# %% [markdown]
# # Sentimental and Alternative Factors

# %%
factors = ['pc_ratio', 'short_int_ratio']

# %%
all_etf_all_factor_df = None
for factor_to_analyze in factors:
    description_factor_to_analyze = factor_description.loc[factor_to_analyze, 'Name']
    print(description_factor_to_analyze)

    #list all etf in datafrome
    all_etf_combined_df = pd.DataFrame()

    #going throw each etf forward return 
    for file in os.listdir('forward return'):
        fr_df = pd.read_csv('forward return/'+file, index_col='Date')
        fr_df['Ticker'] = file[:-4]
        try:
            factor_df = pd.read_csv('factor data/'+factor_to_analyze+'/'+file[:-4]+'.csv', index_col='Date')
            combined_df = fr_df.join(factor_df).rename({factor_to_analyze: 'Factor'}, axis=1)
            combined_df['Factor'] = combined_df['Factor'].fillna(method='ffill')
            all_etf_combined_df = pd.concat([all_etf_combined_df, combined_df.dropna().reset_index()], axis=0, ignore_index=True)
        except:
            continue
    
    all_etf_combined_df = all_etf_combined_df.join(all_tickers.set_index('Ticker'), on='Ticker').dropna()
    all_etf_combined_df = all_etf_combined_df.sort_values(['Date', 'Market', 'Ticker']).set_index(['Date', 'Market', 'Ticker'])[start_date_train:end_date_test]
    all_etf_combined_df['Winsorized Factor'] = np.nan
    all_etf_combined_df['Normalized Winsorized Factor'] = np.nan

    #combine all factors
    for date in all_etf_combined_df.index.get_level_values(0).unique():
        for market in ['Developed', 'Emerging']:
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            n_etf = all_etf_combined_df.loc[date].loc[market].shape[0]
            if n_etf >= 15:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = winsorize(all_etf_combined_df.loc[date].loc[market]['Factor'], limits=1/n_etf)
            elif n_etf > 0:
                all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'] = all_etf_combined_df.loc[date].loc[market]['Factor']
            all_etf_combined_df.loc[date].loc[market]['Normalized Winsorized Factor'] = zscore(all_etf_combined_df.loc[date].loc[market]['Winsorized Factor'])
    all_etf_combined_df = all_etf_combined_df.rename({'Normalized Winsorized Factor': factor_to_analyze}, axis=1)
    if all_etf_all_factor_df is None:
        all_etf_all_factor_df = all_etf_combined_df[['f_rtn', factor_to_analyze]]
    else:
        all_etf_all_factor_df = all_etf_all_factor_df.join(all_etf_combined_df[[factor_to_analyze]], how='outer')
# Out:
# Put/Call Ratio
# Short Interest/Market Capitalization

# %%
all_etf_all_factor_df.reset_index()
# Out:
#              Date     Market Ticker     f_rtn  pc_ratio  short_int_ratio
# 0      2016-01-04  Developed    EWA -0.071979  0.899203         1.801277
# 1      2016-01-04  Developed    EWC -0.013368  0.888940         1.610433
# 2      2016-01-04  Developed    EWD -0.060830 -0.388471        -0.342597
# 3      2016-01-04  Developed    EWG -0.055149 -0.525739        -0.731667
# 4      2016-01-04  Developed    EWH -0.098062 -0.171724         1.033072
# ...           ...        ...    ...       ...       ...              ...
# 32931  2019-12-30   Emerging   GREK -0.038922 -0.902005         0.731432
# 32932  2019-12-30   Emerging    KSA -0.021221 -0.809799         1.902926
# 32933  2019-12-30   Emerging   MCHI -0.042813 -0.039688         0.013867
# 32934  2019-12-30   Emerging    THD -0.082510  0.023937        -1.068088
# 32935  2019-12-30   Emerging    TUR  0.032103  1.122372         1.413595
#
# [32936 rows x 6 columns]

# %%
all_etf_all_factor_df.reset_index().to_csv('modeling data/economic.csv')
